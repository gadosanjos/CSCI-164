# %% [markdown]
# Making predictions
# Predicted values of a fitted estimator are the estimated output values for values of the input features. Predicted values are denoted as yhat, pronounced "y-hat". The .predict() method makes predictions from a fitted estimator. Ex: pred = model.predict(X) assigns the predictions from model for the values of X to pred. Predicted values can be calculated for the original inputs or for new data.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LinearRegression

# %%
# Load the dataset and drop instances with missing values
rides = pd.read_csv("cab_rides.csv").dropna()

# X = dataframe of input features
X = rides[['distance']]

# y = dataframe of the output feature
y = rides[['price']]

# %%
# Initialize the model
linearModel = LinearRegression()

# Fit the model
linearModel.fit(X, y)
# Out:
# LinearRegression()

# %%
# Make predictions for X
linearModel.predict(X)
# Out:
# array([[11.48155079],
#        [11.48155079],
#        [11.48155079],
#        [11.48155079],
#        [11.48155079],
#        [11.48155079],
#        [13.29069145],
#        [13.29069145],
#        [13.29069145],
#        [13.29069145],
#        [13.29069145],
#        [13.29069145],
#        [13.37549492],
#        [13.37549492],
#        [13.37549492],
#        [13.37549492],
#        [13.37549492],
#        [13.37549492],
#        [12.27304983],
#        [12.27304983],
#        [12.27304983],
#        [12.27304983],
#        [12.27304983],
#        [12.27304983],
#        [17.24818666],
#        [17.24818666],
#        [17.24818666],
#        [17.24818666],
#        [17.24818666],
#        [17.24818666],
#        [19.3965412 ],
#        [19.3965412 ],
#        [19.3965412 ],
#        [19.3965412 ],
#        [19.3965412 ],
#        [18.54850651],
#        [18.54850651],
#        [18.54850651],
#        [18.54850651],
#        [18.54850651],
#        [18.54850651],
# ...

# %%
# Make predictions for a new instance
# distance = 2.0 miles
Xnew = pd.DataFrame({'distance': [5.0]})
print(Xnew)
# Out:
#    distance
# 0       5.0

# %%
linearModel.predict(Xnew)
# Out:
# array([[24.37167803]])
